# %%
#Importing the libraries
import cv2 
from ultralytics import YOLO
import time
import requests

# %%
# Load YOLO11n model
model = YOLO("runs/detect/train/weights/best.pt")

# %%
# Telegram Bot Details
BOT_TOKEN = "..."  # Replace with your Telegram bot token
CHAT_ID = "..."  # Replace with your Telegram chat ID

# %%
# Define class names (Replace these with actual names and IDs)
CLASS_NAMES = {
    0: "Cabbage",
    1: "Capsicum",
    2: "orange",
    3: "tomato",
    4:"watermelon"
}

# %%
CLASS_COLORS = {
    0: (255, 0, 0),   # Blue for Cabbage
    1: (0, 255, 255), # Yellow for Capsicum
    2: (0, 165, 255), # Orange for Orange
    3: (0, 255, 0),   # Green for Tomato
    4: (0, 0, 255)    # Red for Watermelon
}

# %%
#Telegram related functions for message delivery
def send_telegram_alert(message):
    """Send a Telegram message"""
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendMessage"
    payload = {"chat_id": CHAT_ID, "text": message}
    response = requests.post(url, json=payload)
    print("✅ Telegram alert sent!", response.json())

# %%
# Load video
video_path = "Input videos/Capsicum-2.mp4"  # Change this to your video file
output_path = "Output videos/Capsicum-2.mp4"
cap = cv2.VideoCapture(video_path)
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = int(cap.get(cv2.CAP_PROP_FPS))  # Get FPS
# Video writer to save output
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# %%
# Track low count alerts for each category
#low_count_start_time = {class_id: None for class_id in CLASS_NAMES}  
#alert_sent = {class_id: False for class_id in CLASS_NAMES}

# %%
# Dictionaries to track detection history
detection_start_time = {}  # Tracks how long a category has been detected
low_count_start_time = {}  # Tracks how long a category is below 5
alert_sent = {}  # Prevent multiple alerts

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("❌ Error: Frame could not be read.")
        send_telegram_alert("❌ Error: Frame could not be read.")
        break

    # Run YOLOv8 detection
    results = model(frame)

    # Dictionary to count detected categories
    category_counts = {}  

    for r in results:
        for box in r.boxes:
            class_id = int(box.cls[0])  # Class index
            confidence = float(box.conf[0])  # Confidence score
            if confidence >= 0.3:  # Filter valid detections
                category_counts[class_id] = category_counts.get(class_id, 0) + 1
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                label = CLASS_NAMES.get(class_id, "Unknown")
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 2.5, (0, 255, 0), 2)

    # Display category counts on video
    y_offset = 75
    for class_id, count in category_counts.items():
        label = CLASS_NAMES.get(class_id, "Unknown")
        cv2.putText(frame, f"{label}: {count}", (20, y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX, 2.5, (0, 0, 255), 2)
        y_offset += 30

    # Save frame to video
    out.write(frame)

    # Current time
    current_time = time.time()

    # Track detected categories
    for class_id, count in category_counts.items():
        # Step 1: If category detected for the first time, start tracking
        if class_id not in detection_start_time:
            detection_start_time[class_id] = current_time
            alert_sent[class_id] = False  # Reset alert flag
        
        # Step 2: If detected for 5+ seconds, it qualifies for low-count tracking
        elif current_time - detection_start_time[class_id] >= 5:
            if count < 5:
                if class_id not in low_count_start_time:
                    low_count_start_time[class_id] = current_time  # Start tracking low count
                elif current_time - low_count_start_time[class_id] >= 5 and not alert_sent[class_id]:
                    send_telegram_alert(f"⚠️ Low {CLASS_NAMES[class_id]} Alert! Only {count} detected for 5+ seconds.")
                    alert_sent[class_id] = True  # Mark alert as sent
            else:
                low_count_start_time.pop(class_id, None)  # Reset low count timer if count is back to normal
                alert_sent[class_id] = False  # Reset alert flag

    # Show frame (optional)
    cv2.imshow("Vegetable Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 Capsicums, 62.7ms
# Speed: 4.6ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 67.3ms
# Speed: 3.0ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.2ms
# Speed: 1.6ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.3ms
# Speed: 2.5ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.6ms
# Speed: 2.5ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.1ms
# Speed: 1.0ms preprocess, 55.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 63.3ms
# Speed: 1.5ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.4ms
# Speed: 2.5ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 62.2ms
# Speed: 4.1ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.0ms
# Speed: 1.1ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.0ms
# Speed: 2.2ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 79.4ms
# Speed: 1.5ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.8ms
# Speed: 1.5ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.5ms
# Speed: 2.5ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 58.3ms
# Speed: 2.1ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 54.9ms
# Speed: 4.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.3ms
# Speed: 1.9ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 47.8ms
# Speed: 2.5ms preprocess, 47.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 48.3ms
# Speed: 2.7ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.1ms
# Speed: 1.0ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 47.9ms
# Speed: 2.3ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 46.7ms
# Speed: 2.0ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.7ms
# Speed: 2.5ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 51.3ms
# Speed: 2.0ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 59.4ms
# Speed: 1.9ms preprocess, 59.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.8ms
# Speed: 2.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 62.5ms
# Speed: 3.6ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.4ms
# Speed: 2.5ms preprocess, 50.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.4ms
# Speed: 2.3ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 60.1ms
# Speed: 1.0ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.5ms
# Speed: 2.5ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 60.8ms
# Speed: 3.4ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.3ms
# Speed: 1.5ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 60.3ms
# Speed: 3.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 77.7ms
# Speed: 2.0ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 48.3ms
# Speed: 2.0ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Capsicums, 50.9ms
# Speed: 2.5ms preprocess, 50.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 60.2ms
# Speed: 2.1ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.4ms
# Speed: 2.0ms preprocess, 49.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.7ms
# Speed: 3.0ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 81.6ms
# Speed: 3.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.6ms
# Speed: 1.3ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 46.8ms
# Speed: 2.4ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.2ms
# Speed: 0.8ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.3ms
# Speed: 2.2ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 70.0ms
# Speed: 2.4ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 58.8ms
# Speed: 2.1ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 53.4ms
# Speed: 2.3ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.9ms
# Speed: 3.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 59.2ms
# Speed: 1.4ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 49.7ms
# Speed: 2.6ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 50.2ms
# Speed: 1.3ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 48.2ms
# Speed: 1.7ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.2ms
# Speed: 2.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Capsicums, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 47.6ms
# Speed: 2.1ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 83.9ms
# Speed: 3.6ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 56.9ms
# Speed: 3.0ms preprocess, 56.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 47.1ms
# Speed: 2.1ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 52.8ms
# Speed: 2.0ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 45.7ms
# Speed: 2.0ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 58.0ms
# Speed: 4.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 53.4ms
# Speed: 1.3ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 51.1ms
# Speed: 2.5ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 64.1ms
# Speed: 5.5ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 50.4ms
# Speed: 2.8ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 48.3ms
# Speed: 2.0ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Telegram alert sent! {'ok': True, 'result': {'message_id': 45, 'from': {'id': 8188314211, 'is_bot': True, 'first_name': 'Task_detection', 'username': 'Task_detection_bot'}, 'chat': {'id': 1443202982, 'first_name': 'Utkarsh', 'last_name': 'Srivastava', 'type': 'private'}, 'date': 1741730304, 'text': '⚠️ Low Capsicum Alert! Only 2 detected for 5+ seconds.'}}
#
# 0: 384x640 2 Capsicums, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 48.2ms
# Speed: 2.0ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 48.8ms
# Speed: 2.0ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 58.2ms
# Speed: 1.5ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 69.7ms
# Speed: 2.0ms preprocess, 69.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 54.4ms
# Speed: 2.0ms preprocess, 54.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 51.8ms
# Speed: 2.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 55.7ms
# Speed: 4.1ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 49.4ms
# Speed: 2.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Capsicums, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ Error: Frame could not be read.
# ✅ Telegram alert sent! {'ok': True, 'result': {'message_id': 46, 'from': {'id': 8188314211, 'is_bot': True, 'first_name': 'Task_detection', 'username': 'Task_detection_bot'}, 'chat': {'id': 1443202982, 'first_name': 'Utkarsh', 'last_name': 'Srivastava', 'type': 'private'}, 'date': 1741730306, 'text': '❌ Error: Frame could not be read.'}}

# %%
print(f"✅ Processed video saved as {output_path}")
# Out:
# ✅ Processed video saved as Output videos/Capsicum-2.mp4
